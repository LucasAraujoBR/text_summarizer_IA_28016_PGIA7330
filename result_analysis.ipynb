# %%
import pandas as pd

# %%
df = pd.read_csv('data/wikihow_results.csv')
df.head()


df.info()

df.describe()

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43777 entries, 0 to 43776
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   headline       43777 non-null  object
#  1   title          43777 non-null  object
#  2   text           43777 non-null  object
#  3   resumo         32681 non-null  object
#  4   classificacao  0 non-null      float64
#  5   metadata       32681 non-null  object
#  6   max_length     43777 non-null  int64
#  7   language       43777 non-null  object
#  8   nivel_ensino   43777 non-null  object
#  9   status         43777 non-null  object
#  10  erro           11096 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 3.7+ MB
# headline             0
# title                0
# text                 0
# resumo           11096
# classificacao    43777
# metadata         11096
# max_length           0
# language             0
# nivel_ensino         0
# ...

# %%
df.head(30)
# Out:
#                                              headline  \
# 0   Keep related supplies in the same area.,\nMake...
# 1   Create a sketch in the NeoPopRealist manner of...
# 2   Get a bachelor’s degree.,\nEnroll in a studio-...
# 3   Start with some experience or interest in art....
# 4   Keep your reference materials, sketches, artic...
# 5   Keep all of your past work organized and acces...
# 6   Create a compelling reel or portfolio.,\nLand ...
# 7   Join a professional society.,\nEnjoy working w...
# 8   Make sure you know what is expected of you.,\n...
# 9   Make a list of what your friends watch, read, ...
# 10  Practice your material until you can perform e...
# 11  Listen to radio advertisements.,\nDetermine th...
# 12  Take theatre classes.,\nVolunteer at a theatre...
# 13  Set up a clear list of traits and characterist...
# 14  Determine if your minivan is currently under w...
# 15  Define the workshop objective.,\nDecide who yo...
# ...

# %%
len(df)
# Out:
# 43777

# %%
df_erro = df[df['status'] == 'erro']
df_ok = df[df['status'] == 'ok']

len(df_erro)
# Out:
# 11096

# %%
len(df_ok)
# Out:
# 32681
